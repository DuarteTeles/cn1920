# %%
# The degree frequencies file should have only one number per line, where the 
# line index (starting at 0) is the degree.
data = open("degree-dist.data")
dist = [int(freq.strip()) for freq in data]
data.close()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

x = np.linspace(1, 10**6, 1000)
starting_offset = 2e6 # Just to align the curve with the data.
estimated_gamma = 1.63 # Get the values from plfit.

plt.xlabel("Vertices")
plt.ylabel("Degree frequency")
plt.xscale("log")
plt.yscale("log")
plt.xlim(1, 5e6)
plt.ylim(1, 1e6)

plt.plot(dist)
plt.plot(t1, starting_offset * x ** -estimated_gamma, linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="640">
